# %%
x = """請分析以下新聞數據：

{news_data}

請回答以下問題：
1. 這些新聞的主要主題是什麼？
2. 有哪些關鍵的數據點或趨勢值得關注？
3. 從可用的分析工具中，應該使用哪些工具來分析這些新聞？請列出工具名稱並說明原因。

{format_instructions}"""

print(x)
# Out:
# 請分析以下新聞數據：
#
# {news_data}
#
# 請回答以下問題：
# 1. 這些新聞的主要主題是什麼？
# 2. 有哪些關鍵的數據點或趨勢值得關注？
# 3. 從可用的分析工具中，應該使用哪些工具來分析這些新聞？請列出工具名稱並說明原因。
#
# {format_instructions}
